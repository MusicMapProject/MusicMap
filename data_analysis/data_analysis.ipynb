# %%
import matplotlib.pyplot as plt
import numpy
import pandas as pd

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data_D = np.asarray(pd.read_csv("../data/labels/D.csv"))
data_S = np.asarray(pd.read_csv("../data/labels/S.csv"))
all_data = np.asarray(pd.read_csv("../data/labels/audio_target.csv"))

# %%
all_data
# Out:
# array([[0, '2D', 3.1, 3.0],
#        [1, '3D', 3.5, 3.3],
#        [2, '4D', 5.7, 5.5],
#        ...,
#        [2543, '997S', 6.7, 6.4],
#        [2544, '999S', 5.9, 4.1],
#        [2545, '1000S', 5.8889, 7.2222]], dtype=object)

# %%
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111)
image = plt.imread('./va_scale.jpg')
plt.imshow(image, extent=[1, 9, 1, 9])

plt.plot(data_D[:150, 2], data_D[:150, 3], 'ro', markersize = '8')
for i, xy in enumerate(zip(data_D[:150, 2], data_D[:150, 3])):                         
    ax.annotate(data_D[:, 1][i], xy, textcoords='data')
    
plt.show()

# %%
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111)
image = plt.imread('../data/labels/va_scale.jpg')
plt.imshow(image, extent=[1, 9, 1, 9])

plt.plot(data_D[:, 2], data_D[:, 3], 'ro', markersize = '8', alpha = 0.3)
# for i, xy in enumerate(zip(data_D[:, 2], data_D[:, 3])):                         
#     ax.annotate(data_D[:, 1][i], xy, textcoords='data')
    
plt.show()

# %%
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111)
image = plt.imread('../data/labels/va_scale.jpg')
plt.imshow(image, extent=[1, 9, 1, 9])

plt.plot(data_S[:, 2], data_S[:, 3], 'ro', markersize = '8', alpha = 0.3)
# for i, xy in enumerate(zip(data_D[:, 2], data_D[:, 3])):                         
#     ax.annotate(data_D[:, 1][i], xy, textcoords='data')
    
plt.show()

# %%
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111)
image = plt.imread('./va_scale.jpg')
plt.imshow(image, extent=[1, 9, 1, 9])

plt.plot(all_data[:, 2], all_data[:, 3], 'ro', markersize = '8', alpha = 0.3)
# for i, xy in enumerate(zip(data_D[:, 2], data_D[:, 3])):                         
#     ax.annotate(data_D[:, 1][i], xy, textcoords='data')
    
plt.show()

# %%
print len(all_data)
# Out:
# 2546
